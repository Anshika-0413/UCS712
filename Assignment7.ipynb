# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#Part 1:
roll_number = 102317059
np.random.seed(roll_number)
sales_data = np.random.randint(1000, 5000, size=(12, 4))
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
categories = ['Electronics', 'Clothing', 'Home & Kitchen', 'Sports']

df = pd.DataFrame(sales_data, columns=categories, index=months)

# Part 2:
print(df.head())
print("\nSummary Statistics:\n", df.describe())
df['Total Sales'] = df.sum(axis=1)
total_sales_per_category = df[categories].sum()
print("\nTotal Sales per Category:\n", total_sales_per_category)
print("\nTotal Sales per Month:\n", df['Total Sales'])


df['Growth Rate'] = df['Total Sales'].pct_change() * 100
df.loc[:, 'Growth Rate'] = df['Growth Rate'].fillna(0)


if roll_number % 2 == 0:
    df['Electronics'] *= 0.90
else:
    df['Clothing'] *= 0.85

print("\nDataFrame after Discount:\n", df)

# Part3:

df[categories].plot(kind='line', figsize=(10, 5), marker='o')
plt.title('Monthly Sales Trends')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.legend()
plt.grid()
plt.show()


plt.figure(figsize=(8, 5))
sns.boxplot(data=df[categories])
plt.title('Sales Distribution by Category')
plt.show()
# Out:
#      Electronics  Clothing  Home & Kitchen  Sports
# Jan         4808      3782            4933    4426
# Feb         3953      1183            1921    3950
# Mar         1212      2829            2793    2295
# Apr         1532      4529            2383    4235
# May         3980      2071            2751    2310
#
# Summary Statistics:
#         Electronics     Clothing  Home & Kitchen       Sports
# count       12.000    12.000000       12.000000    12.000000
# mean      3112.000  2847.416667     3248.916667  3367.333333
# std       1378.577  1312.408505     1147.700346  1125.579958
# min       1165.000  1183.000000     1639.000000  1930.000000
# 25%       1844.750  1971.750000     2416.750000  2233.750000
# 50%       3366.000  2344.500000     2970.500000  3917.500000
# 75%       4114.500  3968.750000     4248.000000  4278.500000
# max       4826.000  4989.000000     4970.000000  4781.000000
#
# Total Sales per Category:
#  Electronics       37344
# Clothing          34169
# Home & Kitchen    38987
# Sports            40408
# dtype: int64
#
# Total Sales per Month:
#  Jan    17949
# Feb    11007
# Mar     9129
# Apr    12679
# May    11112
# Jun    14106
# Jul    14427
# Aug     9676
# Sep    11027
# Oct    15905
# Nov     9874
# Dec    14017
# Name: Total Sales, dtype: int64
#
# DataFrame after Discount:
#       Electronics  Clothing  Home & Kitchen  Sports  Total Sales  Growth Rate
# Jan         4808   3214.70            4933    4426        17949     0.000000
# Feb         3953   1005.55            1921    3950        11007   -38.676249
# Mar         1212   2404.65            2793    2295         9129   -17.061870
# Apr         1532   3849.65            2383    4235        12679    38.887063
# May         3980   1760.35            2751    2310        11112   -12.359019
# Jun         2669   4240.65            4518    1930        14106    26.943844
# Jul         4826   2015.35            3345    3885        14427     2.275627
# Aug         1165   1422.90            2428    4409         9676   -32.931309
# Sep         3564   1925.25            3148    2050        11027    13.962381
# Oct         4518   1970.30            4970    4099        15905    44.236873
# Nov         1949   1279.25            1639    4781         9874   -37.918893
# Dec         3168   3955.05            4158    2038        14017    41.958679

# %%
import numpy as np

array = np.array([[1, -2, 3], [-4, 5, -6]])


abs_values = np.abs(array)
print("Absolute Values:\n", abs_values)

percentiles = {
    "25th": np.percentile(array, 25, axis=None),
    "50th (Median)": np.percentile(array, 50, axis=None),
    "75th": np.percentile(array, 75, axis=None)
}
print("\nPercentiles:", percentiles)


print("\nMean:", np.mean(array))
print("Median:", np.median(array))
print("Standard Deviation:", np.std(array))

print("\nColumn-wise Mean:", np.mean(array, axis=0))
print("Column-wise Median:", np.median(array, axis=0))
print("Column-wise Standard Deviation:", np.std(array, axis=0))

print("\nRow-wise Mean:", np.mean(array, axis=1))
print("Row-wise Median:", np.median(array, axis=1))
print("Row-wise Standard Deviation:", np.std(array, axis=1))
# Out:
# Absolute Values:
#  [[1 2 3]
#  [4 5 6]]
#
# Percentiles: {'25th': np.float64(-3.5), '50th (Median)': np.float64(-0.5), '75th': np.float64(2.5)}
#
# Mean: -0.5
# Median: -0.5
# Standard Deviation: 3.8622100754188224
#
# Column-wise Mean: [-1.5  1.5 -1.5]
# Column-wise Median: [-1.5  1.5 -1.5]
# Column-wise Standard Deviation: [2.5 3.5 4.5]
#
# Row-wise Mean: [ 0.66666667 -1.66666667]
# Row-wise Median: [ 1. -4.]
# Row-wise Standard Deviation: [2.05480467 4.78423336]

# %%
a = np.array([-1.8, -1.6, -0.5, 0.5, 1.6, 1.8, 3.0])
floor_values = np.floor(a)
ceil_values = np.ceil(a)
trunc_values = np.trunc(a)
round_values = np.round(a)

print("Floor Values:", floor_values)
print("Ceiling Values:", ceil_values)
print("Truncated Values:", trunc_values)
print("Rounded Values:", round_values)
# Out:
# Floor Values: [-2. -2. -1.  0.  1.  1.  3.]
# Ceiling Values: [-1. -1. -0.  1.  2.  2.  3.]
# Truncated Values: [-1. -1. -0.  0.  1.  1.  3.]
# Rounded Values: [-2. -2. -0.  0.  2.  2.  3.]

# %%
def swap_list_elements(lst, index1, index2):
    temp = lst[index1]
    lst[index1] = lst[index2]
    lst[index2] = temp
    return lst

lst = [10, 20, 30, 40, 50]
index1, index2 = 1, 3
print("Before Swap:", lst)
print("After Swap:", swap_list_elements(lst, index1, index2))
# Out:
# Before Swap: [10, 20, 30, 40, 50]
# After Swap: [10, 40, 30, 20, 50]

# %%
def swap_set_elements(s, elem1, elem2):
    lst = list(s)
    index1, index2 = lst.index(elem1), lst.index(elem2)


    lst[index1], lst[index2] = lst[index2], lst[index1]

    return set(lst)


s = {1, 2, 3, 4, 5}
elem1, elem2 = 2, 4
print("Before Swap:", s)
print("After Swap:", swap_set_elements(s, elem1, elem2))
# Out:
# Before Swap: {1, 2, 3, 4, 5}
# After Swap: {1, 2, 3, 4, 5}
